# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       2 import sys
#       3 spec = importlib.util.spec_from_file_location("tmsneurosim", "../../../../TMS-Neuro-Sim/tmsneurosim/")
# ----> 4 foo = importlib.util.module_from_spec(spec)
#       5 sys.modules["tmsneurosim"] = foo
#       6 spec.loader.exec_module(foo)
#
# File <frozen importlib._bootstrap>:570, in module_from_spec(spec)
#
# AttributeError: 'NoneType' object has no attribute 'loader'

# %%
import tmsneurosim

# %%
from l23_pc_cadpyr import L23_PC_cADpyr

# %%
cell = L23_PC_cADpyr(1)
cell.load()

# %%
from neuron import h
list(h.allsec())
# Out:
# [<l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.soma[0],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.axon[0],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[0],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[1],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[2],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[3],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[4],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[5],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[6],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[7],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[8],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[9],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[10],
#  <l23_pc_cadpyr.L23_PC_cADpyr object at 0x7faf47fe1d10>.dend[11],
# ...
